# %%
import pandas as p 

data = p.read_csv("thanksgiving.csv",encoding="Latin-1")
data.head()
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
data["Do you celebrate Thanksgiving?"].value_counts()
# Out:
# Yes    980
# No      78
# Name: Do you celebrate Thanksgiving?, dtype: int64

# %%
data=data[data["Do you celebrate Thanksgiving?"]=='Yes']

# %%
data["What is typically the main dish at your Thanksgiving dinner?"].value_counts()
# Out:
# Turkey                    859
# Other (please specify)     35
# Ham/Pork                   29
# Tofurkey                   20
# Chicken                    12
# Roast beef                 11
# I don't know                5
# Turducken                   3
# Name: What is typically the main dish at your Thanksgiving dinner?, dtype: int64

# %%
data[data["What is typically the main dish at your Thanksgiving dinner?"] =="Tofurkey"]["Do you typically have gravy?"]
# Out:
# 4      Yes
# 33     Yes
# 69      No
# 72      No
# 77     Yes
# 145    Yes
# 175    Yes
# 218     No
# 243    Yes
# 275     No
# 393    Yes
# 399    Yes
# 571    Yes
# 594    Yes
# 628     No
# 774     No
# 820     No
# 837    Yes
# 860     No
# 953    Yes
# Name: Do you typically have gravy?, dtype: object

# %%
data[data["What is typically the main dish at your Thanksgiving dinner?"]=="Tofurkey"]
# Out:
#      RespondentID Do you celebrate Thanksgiving?  \
# 4      4337931983                            Yes
# 33     4337771439                            Yes
# 69     4337553422                            Yes
# 72     4337540484                            Yes
# 77     4337490067                            Yes
# 145    4337191550                            Yes
# 175    4337139327                            Yes
# 218    4337078951                            Yes
# 243    4337044348                            Yes
# 275    4336997445                            Yes
# 393    4336894719                            Yes
# 399    4336891075                            Yes
# 571    4336760110                            Yes
# 594    4336736562                            Yes
# 628    4336692873                            Yes
# 774    4336400854                            Yes
# 820    4336238126                            Yes
# 837    4336175740                            Yes
# ...

# %%
data["Do you typically have gravy?"]
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
# 5       Yes
# 6       Yes
# 7       Yes
# 8       Yes
# 9       Yes
# 11       No
# 12      Yes
# 13      Yes
# 14      Yes
# 15      Yes
# 16      Yes
# 17      Yes
# 18      Yes
# 19      Yes
# 20      Yes
# 21      Yes
# 23      Yes
# 24      Yes
# 25      Yes
# 26      Yes
# 27      Yes
# 28      Yes
# 29      Yes
# 30      Yes
# 32      Yes
#        ...
# 1024     No
# 1025    Yes
# 1026    Yes
# 1027    Yes
# 1029    Yes
# 1030    Yes
# 1031    Yes
# 1033    Yes
# 1034    Yes
# 1035    Yes
# 1037     No
# 1038    Yes
# 1039    Yes
# 1040    Yes
# 1041    Yes
# 1042    Yes
# 1043    Yes
# 1044    Yes
# 1045    Yes
# 1046    Yes
# 1047    Yes
# 1048     No
# 1049    Yes
# 1050    Yes
# 1051    Yes
# 1053    Yes
# 1054    Yes
# 1055     No
# 1056    Yes
# 1057    Yes
# Name: Do you typically have gravy?, dtype: object

# %%
apple_isnull=p.isnull(data["Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple"])
apple_isnull.value_counts()
# Out:
# False    514
# True     466
# Name: Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple, dtype: int64

# %%
pumpkin_isnull=p.isnull(data["Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin"])

pumpkin_isnull.value_counts()
# Out:
# False    729
# True     251
# Name: Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin, dtype: int64

# %%
pecan_isnull=p.isnull(data["Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan"])
pecan_isnull.value_counts()
# Out:
# True     638
# False    342
# Name: Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan, dtype: int64

# %%
ate_pies = apple_isnull & pumpkin_isnull & pecan_isnull
ate_pies.value_counts()

string = "Helc - okf"

print(string.split('-')[0].strip()+ "qohoo")
# Out:
# Helcqohoo

# %%
def conv_int (value):
    if p.isnull(value):
        return None
    elif len(value)==3:
        return int(60)
    else:
        return int(value.split('-')[0].strip())
data["int_age"] = data["Age"].apply(conv_int)

data["int_age"].describe()
# Out:
# abf

# %% [markdown]
# # Journey so far
#
# - As the age was provided in range, so for calculation purpose derived the age as the lower limit
#
# ### Pandas.Series.describe()
#
# Generates descriptive statistics that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values.
# Analyzes both numeric and object series, as well as DataFrame column sets of mixed data types. The output will vary depending on what is provided. Refer to the notes below for more detail
#
# ### Pandas.Series.apply()
#
# Invoke function on values of Series. Can be ufunc (a NumPy function that applies to the entire Series) or a Python function that only works on single values. Can apply the function on the entire row
#
# ### Pandas.Series.value_counts()
#
# Groups by the distinct values and returns the values with total counts
#
# ### Pandas.Series.isnull()
#
# Returns a boolean series which has value True if the respective value in the column is null
#
# ### Pandas.dataFrame.head()
#
# Returns the first 5 rows of the dataframe

# %%
def convert_money(value):
    if p.isnull(value):
        return None
    elif "and" in value:
        return int(value.split("and")[0].replace('$','').replace(',','').strip())
    elif "$" in value:
        return int(value.split("to")[0].replace('$','').replace(',','').strip())
    else:
        return None

data["int_income"]=data["How much total combined money did all members of your HOUSEHOLD earn last year?"].apply(convert_money)

print(type(data["int_income"].describe()))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ### Findings
# Although we only have a rough approximation of income, and it skews downward because we took the first value in each string (the lower bound), the average income seems to be fairly high, although there is also a large standard deviation.

# %%
not_rich=data[data["int_income"]<150000]["How far will you travel for Thanksgiving?"].value_counts()
print(not_rich)
rich =data[data["int_income"]>150000]["How far will you travel for Thanksgiving?"].value_counts()
print(rich)
# Out:
# Thanksgiving is happening at my home--I won't travel at all                         281
# Thanksgiving is local--it will take place in the town I live in                     203
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    150
# Thanksgiving is out of town and far away--I have to drive several hours or fly       55
# Name: How far will you travel for Thanksgiving?, dtype: int64
# Thanksgiving is happening at my home--I won't travel at all                         49
# Thanksgiving is local--it will take place in the town I live in                     25
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    16
# Thanksgiving is out of town and far away--I have to drive several hours or fly      12
# Name: How far will you travel for Thanksgiving?, dtype: int64

# %% [markdown]
# ### Findings
# It appears that more people with high income have Thanksgiving at home than people with low income. This may be because younger students, who don't have a high income, tend to go home, whereas parents, who have higher incomes, don't.

# %%
data.pivot_table(
    index="Have you ever tried to meet up with hometown friends on Thanksgiving night?", 
    columns='Have you ever attended a "Friendsgiving?"',
    values="int_age"
)
# Out:
# Have you ever attended a "Friendsgiving?"                  No        Yes
# Have you ever tried to meet up with hometown fr...
# No                                                  42.283702  37.010526
# Yes                                                 41.475410  33.976744

# %%
data.pivot_table(
    index="Have you ever tried to meet up with hometown friends on Thanksgiving night?", 
    columns='Have you ever attended a "Friendsgiving?"',
    values="int_income"
)
# Out:
# Have you ever attended a "Friendsgiving?"                     No           Yes
# Have you ever tried to meet up with hometown fr...
# No                                                  78914.549654  72894.736842
# Yes                                                 78750.000000  66019.736842

# %% [markdown]
# ### Findings
# It appears that people who are younger are more likely to attend a Friendsgiving, and try to meet up with friends on Thanksgiving.
#
# #### DataFrame.pivot_table(values=None, index=None, columns=None, aggfunc='mean')
# To create a group by subset over the selected columns and apply the aggregate functions on the respective values of some other column
